# %% [markdown]
# # Proyecto final

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <div style="background-color:#EDF7FF; border-color: #7C9DBF; border-left:5px solid #7C9DBF; padding: 0.5em;">
# <strong>Nombre y apellidos:</strong> Maite Piedra Yera
# </div>

# %%
data = pd.read_csv('datset_final.csv', sep=',', header=0)
data.head()
# Out:
#   Country Name                                     Indicator Name       2000  \
# 0   Arab World  Access to clean fuels and technologies for coo...  73.702495
# 1   Arab World            Access to electricity (% of population)  78.479364
# 2   Arab World  Access to electricity, rural (% of rural popul...  61.626342
# 3   Arab World  Access to electricity, urban (% of urban popul...        NaN
# 4   Arab World  Account ownership at a financial institution o...        NaN
#
#         2001       2002       2003       2004       2005       2006  \
# 0  74.944860  76.258066  77.120464  78.094440  79.062000  79.851681
# 1  80.023047  77.999111  79.306311  79.537184  80.574728  84.621206
# 2  64.908930  66.246450  64.850152  64.471295  66.612006  72.367301
# 3  94.574429  93.022834  93.321986  93.601289  93.556321  95.141707
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#         2007  ...       2010       2011       2012       2013       2014  \
# ...

# %%
data.shape
# Out:
# (106252, 22)

# %%
data.duplicated().sum()
# Out:
# 77

# %%
data.loc[data.duplicated(keep=False), :]
# Out:
#                  Country Name  \
# 20027          American Samoa
# 20028          American Samoa
# 20431                 Andorra
# 20432                 Andorra
# 22451                   Aruba
# ...                       ...
# 101636         United Kingdom
# 102039          United States
# 102040          United States
# 104463  Virgin Islands (U.S.)
# 104464  Virgin Islands (U.S.)
#
#                                            Indicator Name  2000  2001  2002  \
# 20027   Net official development assistance received (...   NaN   NaN   NaN
# 20028   Net official development assistance received (...   NaN   NaN   NaN
# 20431   Net official development assistance received (...   NaN   NaN   NaN
# 20432   Net official development assistance received (...   NaN   NaN   NaN
# 22451   Net official development assistance received (...   NaN   NaN   NaN
# ...                                                   ...   ...   ...   ...
# ...

# %%
data = data.drop_duplicates(keep='first')

# %%
data.shape
# Out:
# (106175, 22)

# %%
data.duplicated(subset=['Country Name', 'Indicator Name']).sum()
# Out:
# 186

# %%
data.loc[data.duplicated(subset=['Country Name', 'Indicator Name'], keep=False), :]
# Out:
#                           Country Name  \
# 231                         Arab World
# 232                         Arab World
# 635             Caribbean small states
# 636             Caribbean small states
# 1039    Central Europe and the Baltics
# ...                                ...
# 105272                     Yemen, Rep.
# 105675                          Zambia
# 105676                          Zambia
# 106079                        Zimbabwe
# 106080                        Zimbabwe
#
#                                            Indicator Name          2000  \
# 231     Net official development assistance received (...           NaN
# 232     Net official development assistance received (...  5.060030e+09
# 635     Net official development assistance received (...           NaN
# 636     Net official development assistance received (...  1.923900e+08
# 1039    Net official development assistance received (...           NaN
# ...

# %%
data = data.drop_duplicates(subset=['Country Name', 'Indicator Name'], keep='first')

# %%
data.shape
# Out:
# (105989, 22)

# %%
data.duplicated(subset=['Country Name', 'Indicator Name']).sum()
# Out:
# 0

# %%
out_data = data.set_index(['Country Name', 'Indicator Name']).unstack('Country Name').T \
        .rename_axis(index=['Year', 'Country'], columns=None).reset_index()

# %%
out_data.head()
# Out:
#    Year         Country  \
# 0  2000     Afghanistan
# 1  2000         Albania
# 2  2000         Algeria
# 3  2000  American Samoa
# 4  2000         Andorra
#
#    Access to clean fuels and technologies for cooking (% of population)  \
# 0                                               8.80
# 1                                              39.80
# 2                                              86.47
# 3                                                NaN
# 4                                             100.00
#
#    Access to electricity (% of population)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                    100.0
#
#    Access to electricity, rural (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
out_data.shape
# Out:
# (5260, 405)

# %%
out_data.isnull().sum()
# Out:
# Year                                                                                                                                               0
# Country                                                                                                                                            0
# Access to clean fuels and technologies for cooking (% of population)                                                                            1265
# Access to electricity (% of population)                                                                                                          499
# Access to electricity, rural (% of rural population)                                                                                             626
#                                                                                                                                                 ...
# ...

# %%
columnas = list(out_data)

# %%
del columnas[0:2]

# %%
columnas
# Out:
# ['Access to clean fuels and technologies for cooking (% of population)',
#  'Access to electricity (% of population)',
#  'Access to electricity, rural (% of rural population)',
#  'Access to electricity, urban (% of urban population)',
#  'Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)',
#  'Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)',
#  'Account ownership at a financial institution or with a mobile-money-service provider, male (% of population ages 15+)',
#  'Account ownership at a financial institution or with a mobile-money-service provider, older adults (% of population ages 25+)',
#  'Account ownership at a financial institution or with a mobile-money-service provider, poorest 40% (% of population ages 15+)',
# ...

# %%
out_data = out_data.dropna(subset=columnas, how='all')

# %%
out_data.shape
# Out:
# (5259, 405)

# %%
out_data['Year'] = pd.to_datetime(out_data['Year'])

# %%
out_data.to_csv('practica.csv', index=False)
